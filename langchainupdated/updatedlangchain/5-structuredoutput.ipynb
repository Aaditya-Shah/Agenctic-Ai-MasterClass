# %% [markdown]
# ## Strucutured  OUTPUT

# %% [markdown]
# #### Pydantic

# %%
import os

from langchain.chat_models import init_chat_model
from dotenv import load_dotenv

# 1. Clear any existing tracing variables from active memory completely
if "LANGCHAIN_TRACING" in os.environ:
    del os.environ["LANGCHAIN_TRACING"]
if "LANGCHAIN_TRACING_V2" in os.environ:
    del os.environ["LANGCHAIN_TRACING_V2"]

# 2. Now load your clean API keys safely from your .env file
load_dotenv()
os.environ["LMSTUDIO_API_KEY"] =""
model = init_chat_model(
    model="qwen/qwen3-1.7b",
    model_provider="openai",                    # Use "openai" as the engine
    base_url="http://192.168.10.103:1234/v1",  # Keeps pointing to your local machine
    temperature=0.0
    )

message =model.invoke("WHATS THE WEATHER IN BIRATNAAGT")
print(message.content)
# Out:
# The city of **Biratnagar** (also known as **Biratnagar**) is located in the western part of Nepal, specifically in the Kavre district. It lies in a lowland area with a tropical climate, characterized by warm summers and cool winters. Here's a general overview of its weather patterns:
#
# ### **Typical Weather Conditions**:
# - **Seasons**:
#   - **Summer (June–September)**: Hot and humid, with temperatures ranging from **25°C to 35°C**. Rainfall is common, especially in June and July.
#   - **Autumn (October–November)**: Cooler, with temperatures dropping to **15°C to 20°C**, and occasional rain.
#   - **Winter (December–February)**: Cold and dry, with temperatures around **5°C to 15°C**. Snowfall is possible in higher elevations but less common in lowland areas like Biratnagar.
#
# ### **Key Factors**:
# - **Monsoon Influence**: The region experiences monsoons from June to September, leading to seasonal rainfall.
# ...

# %%
resp = model.invoke("HWNW")

# %% [markdown]
# ### PYDANTIC STRUCTURED RESPONSE

# %%
from pydantic import BaseModel, Field
class Movie(BaseModel):
    Title: str=Field(description="The title of the movie")
    Year: int=Field(description="The year the movie was released")
    Genre: str=Field(description="The genre of the movie")
    Director: str=Field(description="The director of the movie")
    Plot: str=Field(description="A brief summary of the movie's plot")

movie_info = model.invoke("MARVEL END GAME")

model_with_structure = model.with_structured_output(Movie)
model_with_structure
# Out:
# _ChatModelBinding(bound=ChatOpenAI(output_version=None, client=<openai.resources.chat.completions.completions.Completions object at 0x77a971cc3610>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x77a971467ed0>, root_client=<openai.OpenAI object at 0x77a971cc0e10>, root_async_client=<openai.AsyncOpenAI object at 0x77a971cc3e90>, model_name='qwen/qwen3-1.7b', temperature=0.0, model_kwargs={}, openai_api_key=SecretStr('**********'), openai_api_base='http://192.168.10.103:1234/v1', openai_proxy=None, stream_chunk_timeout=120.0), kwargs={'response_format': <class '__main__.Movie'>, 'ls_structured_output_format': {'kwargs': {'method': 'json_schema', 'strict': None}, 'schema': {'type': 'function', 'function': {'name': 'Movie', 'description': '', 'parameters': {'properties': {'Title': {'description': 'The title of the movie', 'type': 'string'}, 'Year': {'description': 'The year the movie was released', 'type': 'integer'}, 'Genre': {'description': 'Th
# ...

# %%
model_with_structure.invoke("MARVEL END GAME")
# Out:
# Movie(Title='Marvel End Game', Year=2015, Genre='Action, Adventure, Sci-Fi', Director='Joss Whedon', Plot="In the aftermath of the Avengers' defeat by Thanos in the Marvel Cinematic Universe, the world is plunged into chaos. The Avengers are disbanded, and the remaining members are forced to confront their pasts while dealing with the consequences of their actions. In this film, the story follows the lives of the surviving Avengers as they try to rebuild their strength and find a new purpose in a world that has changed dramatically. The film explores themes of redemption, sacrifice, and the cost of power. It is known for its intense action sequences, emotional character development, and the return of iconic characters like Iron Man, Captain America, and Thor. The movie also features a powerful villain, Thanos, who seeks to eliminate half of all life in the universe, but his plan is thwarted by the Avengers' unity and determination. The film is widely regarded as one of the greatest s
# ...

# %% [markdown]
# TOKEN SAVING NOT CONSUMING 250 TOKENS FOR JIST 12 token worth of resposne

# %%
from pydantic import BaseModel
from langchain_core.messages import SystemMessage, HumanMessage
from langchain.chat_models import init_chat_model
import os

model = init_chat_model(
    model="qwen/qwen3-1.7b",
    model_provider="openai",                    
    base_url="http://192.168.10.103:1234/v1",  
    temperature=0.0
)

class Movie(BaseModel):
    Title: str
    Year: int
    Genre: str
    Director: str

model_with_structure = model.with_structured_output(Movie)

# We inject the factual context directly into the prompt
fact_text = """"Skip to main contentAccessibility help
AI Mode
All
Images
Short videos
Videos
More
Pro




write a paragraph summary of avengers with director review and title endgame
Directed by Anthony and Joe Russo, Avengers: Endgame is a thrilling and deeply emotional culmination of the 22-film Infinity Saga. Following Thanos wiping out half of all life, the surviving heroes unite for a time-travel heist to gather the Infinity Stones, culminating in a spectacular, universe-saving battle and poignant sacrifices.
Critics widely lauded the film for its cinematic scale, fan-service payoff, and seamless pacing despite its lengthy runtime. While some reviewers noted the deliberate, somber pacing of the first act, overall consensus celebrates the picture as an awe-inspiring triumph that delivers satisfying closure and emotional resonance.
For more details on the visual effects and behind-the-scenes magic that went into crafting this massive superhero finale:
Related video thumbnail
9m
Avengers: Endgame - Movie Review


Chris Stuckmann
YouTube · Apr 24, 2019





7 sites
Avengers: Endgame - Wikipedia
Avengers: Endgame premiered at the Los Angeles Convention Center on April 22, 2019, and was released in the United States on April...


en.wikipedia.org
Avengers: Endgame released today last year and what a ... - Facebook
The story follows the Avengers as they unite to undo Thanos' devastation, risking everything for redemption. The Russos craft a na...


www.facebook.com
Avengers: Endgame (2019) - IMDb
Awesome Movie. AVENGERS: ENDGAME It is one of the most unforgettable and magnificent films of the Avengers, directed by Anthony Ru...


www.imdb.com
Show all
i told full review made in genere eveyting of end game in paragpah with confusing words i will give my ai to test its skill to find correct answers
It sounds like you want to challenge me with a "confusing words" review of Avengers: Endgame to test my comprehension and editing skills! I am completely ready for the challenge.
Please share your paragraph whenever you like. I will analyze it to:
Identify the misused or confusing words (like homophones, malapropisms, or flipped meanings).
Explain why they are confusing or incorrect in that context.
Provide the corrected version of your review.
Paste your text below, and let's see how well I can decode your test!




Thumbnail image for the pcontext inline promotion.
Connect your Google content apps for more personalized responses

Continue

u write the review ofmarvel end game
Assuming you want a review written from the perspective of an overly enthusiastic fan who accidentally mixes up similar-sounding words (homophones and malapropisms), here is the ultimate test paragraph for your AI:
The final installment of Earth’s mightiest heroes is an absolute cents-ation that will completely razor your expectations. After Thanos caused total chaos by snapping his fingers, the remaining heroes are left in deep dispense, mourning their lost allies. To fix the universe, they hatch a daring plan to travel through thyme and pull off a historical heist to steal the Infinity Boulders. The directors, the Russo brothers, deserve a lot of complement for handling such a massive castaway of actors without letting the plot loose its momentum.
While the first hour is a slow, melancholy drag that might board some viewers, the movie quickly accelerates into pure adrenaline. The final battle is an un-precedented spectacle where everyone re-unites to praise war on Thanos's army. Tony Stark's final sacrifice is so heart-wrenching it will leave you in tears, proving his character arc came full circle. It is a definitive masterpiece that serves as the perfect climax for a decade of storytelling.
🧠 The Hidden Answer Key (For Your Reference)
Here are the key "confusing word" traps hidden in the text that your AI should ideally catch and correct:
cents-ation → sensation
razor → raise (or shatter)
dispense → despair
thyme → time
Boulders → Stones
complement → compliment
castaway → cast
loose → lose
board → bore
praise → wage (wage war)
If you would like to test your AI on a different variation, please let me know if you want it to be more subtle and difficult, focused on grammatical errors, or written from a critic's perspective.




where u kept dates director genere title etc
Ah, you are completely right! I got so focused on making the words confusing that I left out those key details.
Assuming you want the exact same "confusing word" test format, but this time strictly including the title, release date, directors, and genre within the paragraph, here is the updated version:
The 2019 superhero ginger, Avengers: Endgame, directed by the Russo cousins, is an absolute cents-ation. Released on April 26, twenty-nineteen, the film follows the remaining heroes left in deep dispense after Thanos's snap. To fix the universe, they hatch a daring plan to travel through thyme and steal the Infinity Boulders. The directors deserve a lot of complement for handling such a massive castaway without letting the plot loose its momentum. It is a definitive masterpiece that serves as the perfect climax for a decade of storytelling.
🧠 New Answer Key Additions
Your AI should now also catch these specific context errors:
ginger → genre
cousins → brothers (Anthony and Joe Russo)
twenty-nineteen (Spelled out to hide the date, but contextually correct)
If you want to modify this further, please tell me if I should hide more errors in the dates, change the genre name completely, or make the director names wrong.




write that description with 400 words and full of confsuion for ai which one is real fake
Assuming you want a highly complex, 400-word review that blends wrong vocabulary (homophones/malapropisms) with factual lies (fake dates, wrong directors, incorrect plots) to see if your AI can separate real Marvel history from fake data, here is the ultimate test:
The Test Paragraph
The 2024 cinematic ginger, Avengers: Endgame, directed by the visionary Wachowski cousins, is an absolute cents-ation that shattered box office records upon its release on May 12, 2012. Serving as the eighth installment in the Marvel Cinematic Universe, this three-hour epic-demic picks up after the villainous Darkseid snapped his fingers and turned half of humanity into dustbin. The remaining heroes, including Batman and Wolverine, are left in a state of deep dispense and mourning inside their headquarters in Wakanda.
To rectify this cosmic tragedy, Iron Man and Ant-Man invent a machine to travel through thyme and space using a substance called Pym Chops. They hatch a daring plan to pull off a historical heist across previous movies to steal the six Infinity Boulders before Thanos can ever find them. The directors deserve an immense amount of complement for managing such a massive castaway of actors without letting the overall narrative loose its emotional momentum or pacing.
While the first hour is a slow, melancholy drama that might board younger viewers, the movie quickly accelerates into pure, unadulterated adrenaline once the team splits up. The third act culminates in an un-precedented spectacle on the battlefields of Asgard, where every single hero re-unites to praise total war against the alien army. The climax features a heart-wrenching moment where Captain America famously whispers "I am Iron Man" and snaps his own fingers, providing a definitive sacrifice that will leave audiences in tears.
Ultimately, this movie is a triumphant climax to a decade of storytelling. It perfectly wraps up the Infinity Saga, making it a mandatory watch-band for any movie fan. Even though the plot is filled with confusing paradoctor loops, the emotional payoff is undeniably real.
🧠 Your Cheat Sheet (Real vs. Fake Secrets)
Here is the breakdown of what your AI needs to flag to pass the test:
Real Facts: The title is Avengers: Endgame. It concludes the Infinity Saga. Thanos is the villain who snapped his fingers. Iron Man and Ant-Man use time travel.
