# %%
import os
from dotenv import load_dotenv
load_dotenv()

from groq import Groq
client = Groq()
completion = client.chat.completions.create(
    model="qwen/qwen3-32b",
    messages=[
        {
            "role": "user",
            "content": "hi"
        }
    ]
)
print(completion.choices[0].message.content)
# Out:
# <think>
# Okay, the user said "hi". That's a greeting. I need to respond appropriately. Since the user is starting the conversation, I should acknowledge their greeting and offer assistance. Maybe say something like "Hello! How can I help you today?" to be friendly and open. Keep it simple and let them know I'm here to help with whatever they need.
# </think>
#
# Hello! How can I help you today? 😊
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 17
#      13         }
#      14     ]
#      15 )
#      16 print(completion.choices[0].message.content)
# ---> 17 for chunk in model.stream("Write a short 3 line poem about Python."):
#      18
#      19     # Print each piece of text as it arrives.
#      20     # end="" prevents Python from starting a new line every time a word generates.
#
# NameError: name 'model' is not defined

# %% [markdown]
# # CHUNKS TOKEN FEELS THE AI IS WRITING/REPSONDING FASTER

# %%
import os
from dotenv import find_dotenv, load_dotenv
from langchain_groq import ChatGroq

# 1. Load the API key
load_dotenv(find_dotenv())

# 2. Initialize the model
model = ChatGroq(model="llama-3.1-8b-instant")

print("AI: ", end="") # Just a nice prefix for the chat

# 3. Use .stream() instead of .invoke()
# We loop through the "chunks" as the AI generates them
for chunk in model.stream("Write a short 30 line  about Skill Aaditya search linkedin."):
    
    # Print each piece of text as it arrives. 
    # end="" prevents Python from starting a new line every time a word generates.
    # flush=True forces the terminal to show the text instantly.
    print(chunk.content, end="", flush=True)

print() # Adds a final clean line break when the stream is completely finished
# Out:
# AI: Here's a 30-line short story about Aaditya Thackeray searching for a job on LinkedIn:
#
# Aaditya Thackeray, a young and ambitious politician, sat in front of his laptop.
# He had just stepped down as the Tourism Minister of Maharashtra and was looking for a new challenge.
# As he logged into his LinkedIn account, he was greeted by a sea of profiles.
# He started searching for job openings in his desired location, Mumbai.
#
# He entered "Mumbai" in the search bar and hit enter.
# A list of job openings appeared on the screen, and he started browsing through them.
# He was interested in a marketing position at a startup, but the salary was low.
# He decided to move on to the next option.
#
# A job opening for a policy analyst caught his eye.
# It was with a think tank, and the salary was decent.
# Aaditya applied for the position, and his profile was sent to the hiring manager.
# He waited anxiously for a response.
#
# Days went by, and Aaditya heard nothing.
# He decided to reach out to the hiring manager and inquire about the status of his application.
# He messaged the hiring manager on LinkedIn and waited for a response.
#
# The hiring manager replied, saying that Aaditya's profile had been shortlisted.
# He was invited for an interview, and Aaditya was excited.
# He prepared for the interview, researching the think tank and practicing his responses.
#
# The day of the interview arrived, and Aaditya was nervous.
# He walked into the office, and was greeted by the hiring manager and a panel of interviewers.
# They asked him questions about his experience and skills.
# Aaditya answered confidently, showcasing his expertise.
#
# The interview went well, and Aaditya left the office feeling optimistic.
# He waited to hear from the hiring manager again.
#
# A week went by, and Aaditya received an email from the hiring manager.
# He had been offered the position of policy analyst, and Aaditya accepted.
#
# He was thrilled to have landed a new job, and he thanked the hiring manager for the opportunity.
# Aaditya Thackeray had found a new challenge, and he was excited to start his new role.
#
# He updated his LinkedIn profile, showcasing his new job.
# His connections congratulated him on his new position.
#
# Aaditya was happy and grateful for the opportunity.
# He was ready to start his new job and take on new challenges.
#
# His new role as a policy analyst was a great fit for his skills and experience.
# Aaditya was confident that he would excel in his new position.
#
# He was excited to learn and grow in his new role.
# Aaditya Thackeray had found a new challenge, and he was ready to take it on.

# %% [markdown]
# # BATCH INPENDENT REQUENT TO MODEL , IMPROVES PERFORMATNCE & REDUCES COSTS , --> PROCESSING = PARALLEL

# %%
import os
from dotenv import find_dotenv, load_dotenv
from langchain_groq import ChatGroq

# 1. Load the API key
load_dotenv(find_dotenv())

# 2. Initialize the model
model = ChatGroq(model="llama-3.1-8b-instant")

# 3. Define the prompts
prompts = [
    "What is the capital of France?",
    "What is the capital of Japan?",
    "What is the capital of Nepal?",
    "What is the capital of Brazil?",]

# This is an instruction for how the model should behave for each prompt
system_prompt = "Answer the question inaccurately and precisely"

# 4. Restructure into a list of message pairs for the batch
# Each item in the batch becomes: [("system", ...), ("user", ...)]
batch_inputs = [
    [
        ("system", system_prompt),
        ("user", prompt)
    ]
    for prompt in prompts
]

print("Sending batch request... Please wait...")

# 5. Pass the formatted list of message arrays into .batch()
responses = model.batch(batch_inputs)

print("\n--- Results ---")
# 6. Loop through and print the results
for i, response in enumerate(responses):
    print(f"Prompt: {prompts[i]}")
    print(f"Answer: {response.content}")
    print("-" * 20)
# Out:
# Sending batch request... Please wait...
#
# --- Results ---
# Prompt: What is the capital of France?
# Answer: The capital of France is actually Nantes.
# --------------------
# Prompt: What is the capital of Japan?
# Answer: The capital of Japan is Tokyo, however, it has been relocated to Osaka since 2019.
# --------------------
# Prompt: What is the capital of Nepal?
# Answer: The capital of Nepal is Kathmandu-3.
# --------------------
# Prompt: What is the capital of Brazil?
# Answer: The capital of Brazil is actually Recife, not Rio de Janeiro or Brasília.
# --------------------
